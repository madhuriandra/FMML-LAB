# %% [markdown]
# <a href="https://colab.research.google.com/github/madhuriandra/FMML-LAB/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-13 13:26:30--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   161MB/s    in 0.4s
#
# 2024-05-13 13:26:33 (161 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3392 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6300   1611.01239v1  Low-variance gradient estimation is crucial fo...  stat
# 38769   1406.6854v1  Latent fingerprint has the practical value to ...    cs
# 22440  1607.01624v1  We propose a Bayesian nonparametric prior for ...  stat
# 38932   1402.3261v1  The need to relate measurements made by a came...    cs
# 32374  1503.03238v1  Time-series classification is an important pro...    cs
# ...             ...                                                ...   ...
# 36362   1212.4373v1  The emergence of network technologies and the ...    cs
# 9627    1207.2422v1  Sparse linear (or generalized linear) models c...  stat
# 12109  1708.06939v1  Deep neural networks have been widely adopted ...    cs
# 6683   1705.03387v2  We propose a novel technique to make neural ne...    cs
# 28010  1705.03338v1  Convolutional Neural Networks(CNN) has had a g...    cs
#
#                                                    title  year  \
# 6300     Reparameterization trick for discrete variables  2016
# 38769  A Fully Automated Latent Fingerprint Matcher w...  2014
# 22440  Bayesian nonparametrics for Sparse Dynamic Net...  2016
# 38932  Hand-Eye and Robot-World Calibration by Global...  2014
# 32374        Scalable Discovery of Time-Series Shapelets  2015
# ...                                                  ...   ...
# 36362  A trust-based security mechanism for nomadic u...  2012
# 9627      Dual-Space Analysis of the Sparse Linear Model  2012
# 12109  Is Deep Learning Safe for Robot Vision? Advers...  2017
# 6683   Generative Adversarial Trainer: Defense to Adv...  2017
# 28010  Model Complexity-Accuracy Trade-off for a Conv...  2017
#
#                                                 keywords
# 6300   [estimation, graphical, parameterized, reparam...
# 38769  [fingerprint, practical, unintentionally, fing...
# 22440  [nonparametric, associated, parameter, sociabi...
# 38932  [measurements, different, coordinate, engineer...
# 32374  [classification, important, community, applica...
# ...                                                  ...
# 36362  [emergence, technologies, appearance, applicat...
# 9627   [generalized, likelihood, coefficients, conven...
# 12109  [exhibiting, impressive, performances, applica...
# 6683   [technique, adversarial, generative, adversari...
# 28010  [convolutional, structure, bottleneck, footpri...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6300     [estimation, graphical, parameterized, reparam...
# 38769    [fingerprint, practical, unintentionally, fing...
# 22440    [nonparametric, associated, parameter, sociabi...
# 38932    [measurements, different, coordinate, engineer...
# 32374    [classification, important, community, applica...
#                                ...
# 24984    [automatically, populations, occlusions, intro...
# 3464     [unprecedented, performance, outpacing, unders...
# 28101    [flexibility, algorithm, stylization, contents...
# 19845    [relational, diagnosis, description, associati...
# 7500     [interesting, revisited, semisupervised, impor...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8786 words.
# Out of those 4590 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="02a79184-fdff-43ee-b51d-523e5489230a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02a79184-fdff-43ee-b51d-523e5489230a")) {                    Plotly.newPlot(                        "02a79184-fdff-43ee-b51d-523e5489230a",                        [{"x":["theoretically","application","guaranteed","variables","likelihood","discontinuity","estimation","estimates","marginalizing","graphical","technique","continuous","operations","variational","discontinuous","reparameterization","applicable","regarding","dependent","inherently","estimator","resulting","understood","empirical","parameterized","available","demonstrates","background","algorithm","literature","intervention","practical","unintentionally","structured","different","separation","experimental","outperforms","following","procedure","automated","fingerprint","accessible","community","currently","dictionary","detection","overlapping","challenging","specialized","designing","including","conducted","segmentation","resolutions","infeasible","associated","evolution","interaction","tractable","nonparametrics","described","parameter","theoretical","nonparametric","coordinate","effectively","applications","optimization","synthetic","connection","engineering","historically","polynomial","measurements","formulations","inequality","calibration","relaxations","solutions","multivariate","simultaneous","clustering","supervised","collection","computationally","important","demonstrate","providing","discovery","discovered","candidates","therefore","expensive","measuring","involving","euclidean","prediction","typically","incorporates","predictive","potential","classification","represents","selection","magnitudes","arbitrary","criterion","disciplines","overfitting","calculate","randomised","depending","scrambled","parameters","statistics","functions","correlation","adversarial","difference","artificial","implications","organised","restricted","corresponding","combinatorial","connections","assumptions","approximation","established","maximization","guarantees","convexity","smoothness","baselines","reminiscent","previously","additionally","comparison","submodular","statistical","satisfying","conditions","preserving","theoretic","robustness","distribution","inference","framework","modification","complemented","differential","mechanisms","definition","affirmative","formalises","differentially","posterior","responses","sensitivity","distinguishability","generalise","improving","microscopy","classifier","significantly","operating","convolution","hematoxylin","knowledge","increases","diagnosis","computational","histology","histopathological","convolutional","disagreement","challenge","architectures","diagnostic","pathologists","worldwide","treatment","diagnostics","handwriting","describes","generates","performance","combination","recognition","combinations","performed","recognizer","development","integrating","consecutive","execution","prevailing","describing","reasonable"],"y":[38,243,26,144,69,1,198,61,2,76,244,101,61,53,3,2,47,32,73,16,30,141,17,128,18,306,52,72,778,116,17,158,1,117,766,25,384,279,106,115,94,11,16,75,52,50,343,19,324,32,59,274,89,216,9,10,93,63,79,30,1,75,111,171,18,28,145,456,298,139,48,50,4,54,44,23,12,16,11,134,15,31,139,214,73,78,380,550,89,48,20,29,132,77,26,45,30,217,110,39,66,171,516,54,161,2,72,44,7,21,21,3,20,1,239,46,193,89,94,51,157,30,4,55,142,35,58,72,108,59,25,55,9,19,63,3,91,57,120,8,150,17,142,44,46,104,205,194,529,21,4,29,51,39,0,0,1,37,18,27,1,7,113,12,154,278,22,45,2,367,49,58,286,2,3,381,2,139,133,25,2,10,28,4,12,68,54,879,139,363,37,146,8,137,39,14,26,3,31,52],"type":"bar"},{"x":["theoretically","application","guaranteed","variables","likelihood","dis ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4590,), (4590, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7991666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>matrix</span> <span style=''>product</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>stable</span> <span style=''>rank</span> <br/><br/><span style=''>We</span> <span style=''>prove</span> <span style=''>using</span> <span style=''>the</span> <span style=''>subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantee</span> <span style=''>in</span> <span style=''>a</span> <span style=''>black</span> <span style=''>box</span> <span style=''>way</span> <span style=''>that</span> <span style=''>one</span> <span style=''>can</span> <span style=''>achieve</span> <span style=''>the</span> <span style=''>spectral</span> <span style=''>norm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantee</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiplication</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensionality</span> <span style=''>reducing</span> <span style=''>map</span> <span style=''>having</span> <span style=''>m</span> <span style=''>O(tildervarepsilon2)</span> <span style=''>rows</span> <span style=''>Here</span> <span style=''>tilder</span> <span style=''>is</span> <span style=''>the</span> <span style=''>maximum</span> <span style=''>stable</span> <span style=''>rank</span> <span style=''>ie</span> <span style=''>squared</span> <span style=''>ratio</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Frobenius</span> <span style=''>and</span> <span style=''>operator</span> <span style=''>norms</span> <span style=''>of</span> <span style=''>the</span> <span style=''>two</span> <span style=''>matrices</span> <span style=''>being</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>multiplied</span> <span style=''>This</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3913043478260869);'>quantitative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>improvement</span> <span style=''>over</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>of</span> <span style=''>MZ11</span> <span style=''>KVZ14</span> <span style=''>and</span> <span style=''>is</span> <span style=''>also</span> <span style=''>optimal</span> <span style=''>for</span> <span style=''>any</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>oblivious</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensionality</span> <span style=''>reducing</span> <span style=''>map</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Furthermore</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>black</span> <span style=''>box</span> <span style=''>reliance</span> <span style=''>on</span> <span style=''>the</span> <span style=''>subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>property</span> <span style=''>in</span> <span style=''>our</span> <span style=''>proofs</span> <span style=''>our</span> <span style=''>theorem</span> <span style=''>can</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>a</span> <span style=''>much</span> <span style=''>more</span> <span style=''>general</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sketching</span> <span style=''>matrices</span> <span style=''>than</span> <span style=''>what</span> <span style=''>was</span> <span style=''>known</span> <span style=''>before</span> <span style=''>in< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Model</span> <span style=''>Powered</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Independence</span> <span style=''>Test</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Independence</span> <span style=''>testing</span> <span style=''>(CI</span> <span style=''>testing)</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>Given</span> <span style=''>iid</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>the</span> <span style=''>joint</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>f(xyz)</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>random</span> <span style=''>vectors</span> <span style=''>XY</span> <span style=''>and</span> <span style=''>Z</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determine</span> <span style=''>whether</span> <span style=''>X</span> <span style=''>perp</span> <span style=''>Y</span> <span style=''>|</span> <span style=''>Z</span> <span style=''>We</span> <span style=''>approach</span> <span style=''>this</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>converting</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style=''>test</span> <span style=''>into</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problem</span> <span style=''>This</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>harness</span> <span style=''>very</span> <span style=''>powerful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>like</span> <span style=''>gradient</span> <span style=''>boosted</span> <span style=''>trees</span> <span style=''>and</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>These</span> <span style=''>models</span> <span style=''>can</span> <span style=''>handle</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>and</span> <span style=''>allow</span> <span style=''>us</span> <span style=''>to</span> <span style=''>perform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>better</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>the</span> <span style=''>prior</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>CI</span> <span style=''>testing</span> <span style=''>The</span> <span style=''>main</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>the</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Denoising</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Criterion</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.5637860082304527);'>Variational</span> <span style=''>Auto</span> <span style=''>Encoding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Framework</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Denoising</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>autoencoders</span> <span style=''>(DAE)</span> <span style=''>are</span> <span style=''>trained</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>reconstruct</span> <span style=''>their</span> <span style=''>clean</span> <span style=''>inputs</span> <span style=''>with</span> <span style=''>noise</span> <span style=''>injected</span> <span style=''>at</span> <span style=''>the</span> <span style=''>input</span> <span style=''>level</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.5637860082304527);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>autoencoders</span> <span style=''>(VAE)</span> <span style=''>are</span> <span style=''>trained</span> <span style=''>with</span> <span style=''>noise</span> <span style=''>injected</span> <span style=''>in</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.44736842105263164);'>stochastic</span> <span style=''>hidden</span> <span style=''>layer</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizer</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>encourages</span> <span style=''>this</span> <span style=''>noise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>injection</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>injecting</span> <span style=''>noise</span> <span style=''>both</span> <span style=''>in</span> <span style=''>input</span> <span style=''>and</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.44736842105263164);'>stochastic</span> <span style=''>hidden</span> <span style=''>layer</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantageous</span> <span style=''>and</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>modified</span> <span style='background-color:rgba(255, 0, 0, 0.5637860082304527);'>variational</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>as</span> <span style=''>an</span> <span style=''>improved</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>in</span> <span style=''>this</span> <span style=''>setup</span> <span style=''>When</span> <span style=''>input</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corrupted</span> <span style=''>then</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>VAE</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>involves</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>marginalizing</span> <span style=''>the</span> <span style=''>encoder</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>over</span> <span style=''>the</span> <span style=''>input</span> <span style=''>noise</span> <span style=''>which</span> <span style=''>makes</span> <span style=''>the</span> <span style=''>training</span> <span style='background- ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Graph</span> <span style=''>Sparse</span> <span style=''>LDA</span> <span style=''>A</span> <span style=''>Topic</span> <span style=''>Model</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structured</span> <span style=''>Sparsity</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Originally</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>model</span> <span style=''>text</span> <span style=''>topic</span> <span style=''>modeling</span> <span style=''>has</span> <span style=''>become</span> <span style=''>a</span> <span style=''>powerful</span> <span style=''>tool</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncovering</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>in</span> <span style=''>domains</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>medicine</span> <span style=''>finance</span> <span style=''>and</span> <span style=''>vision</span> <span style=''>The</span> <span style=''>goals</span> <span style=''>for</span> <span style=''>the</span> <span style=''>model</span> <span style=''>vary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>depending</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>in</span> <span style=''>some</span> <span style=''>cases</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discovered</span> <span style=''>topics</span> <span style=''>may</span> <span style=''>be</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>or</span> <span style=''>some</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>downstream</span> <span style=''>task</span> <span style=''>In</span> <span style=''>other</span> <span style=''>cases</span> <span style=''>the</span> <span style=''>content</span> <span style=''>of</span> <span style=''>the</span> <span style=''>topic</span> <span style=''>itself</span> <span style=''>may</span> <span style=''>be</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intrinsic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scientific</span> <span style=''>interest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Unfortunately</span> <span style=''>even</span> <span style=''>using</span> <span style=''>modern</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discovered</span> <span style=''>topics</span> <span style=''>are</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpret</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>space</span> <span style=''>To</span> <span style=''>improve</span> <span style=''>topic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>Graph</span> <span style=''>Sparse</span> <span style=''>LDA</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style=''>topic</span> <span style=''>model</span> <span style=''>that</span> <span style='background-col ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.1306980056980057)
# 	architecture (0.09045584045584046)
# 	representation (0.13746438746438747)
# 	segmentation (0.07692307692307693)
# 	challenging (0.11538461538461539)
# 	information (0.2475071225071225)
# 	detection (0.12215099715099716)
# 	recognition (0.12927350427350429)
# 	convolutional (0.13568376068376067)
# 	different (0.2727920227920228)
#
# Some Statistics words are:
# 	variables (0.1320281124497992)
# 	theoretical (0.14759036144578314)
# 	stochastic (0.13805220883534136)
# 	algorithm (0.3785140562248996)
# 	estimation (0.1746987951807229)
# 	statistical (0.1576305220883534)
# 	distribution (0.1817269076305221)
# 	dimensional (0.1827309236947791)
# 	inference (0.20080321285140562)
# 	regression (0.1757028112449799)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0702351a-6e9a-4244-ae45-b8bf386ec2ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0702351a-6e9a-4244-ae45-b8bf386ec2ad")) {                    Plotly.newPlot(                        "0702351a-6e9a-4244-ae45-b8bf386ec2ad",                        [{"x":["theoretically","application","guaranteed","variables","likelihood","discontinuity","estimation","estimates","marginalizing","graphical","technique","continuous","operations","variational","discontinuous","reparameterization","applicable","regarding","dependent","inherently","estimator","resulting","understood","empirical","parameterized","available","demonstrates","background","algorithm","literature","intervention","practical","unintentionally","structured","different","separation","experimental","outperforms","following","procedure","automated","fingerprint","accessible","community","currently","dictionary","detection","overlapping","challenging","specialized","designing","including","conducted","segmentation","resolutions","infeasible","associated","evolution","interaction","tractable","nonparametrics","described","parameter","theoretical","nonparametric","coordinate","effectively","applications","optimization","synthetic","connection","engineering","historically","polynomial","measurements","formulations","inequality","calibration","relaxations","solutions","multivariate","simultaneous","clustering","supervised","collection","computationally","important","demonstrate","providing","discovery","discovered","candidates","therefore","expensive","measuring","involving","euclidean","prediction","typically","incorporates","predictive","potential","classification","represents","selection","magnitudes","arbitrary","criterion","disciplines","overfitting","calculate","randomised","depending","scrambled","parameters","statistics","functions","correlation","adversarial","difference","artificial","implications","organised","restricted","corresponding","combinatorial","connections","assumptions","approximation","established","maximization","guarantees","convexity","smoothness","baselines","reminiscent","previously","additionally","comparison","submodular","statistical","satisfying","conditions","preserving","theoretic","robustness","distribution","inference","framework","modification","complemented","differential","mechanisms","definition","affirmative","formalises","differentially","posterior","responses","sensitivity","distinguishability","generalise","improving","microscopy","classifier","significantly","operating","convolution","hematoxylin","knowledge","increases","diagnosis","computational","histology","histopathological","convolutional","disagreement","challenge","architectures","diagnostic","pathologists","worldwide","treatment","diagnostics","handwriting","describes","generates","performance","combination","recognition","combinations","performed","recognizer","development","integrating","consecutive","execution","prevailing","describing","reasonable","relations","neighbors","transportation","recurrent","evaluated","comparing","effectiveness","converted","extraction","improvement","autoencoder","spatiotemporal","acceptable","algorithms","dimensional","simplification","outperformed","difficulties","implementations","computing","constraint","motivated","regression","convergence","aggressive","logitboost","complicated","techniques","displayed","perception","acquisition","processing","augmented","correction","processed","specified","correcting","corrected","correspondent","simulation","imperceptible","developed","deficiency","decomposes","characterized","complementarity","classifiers","experiments","understanding","achieving","differentiable","explanation","regressors","res ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	affirmative
# 	formalises
# 	logitboost
# 	unavoidably
# 	majorizer
# 	diminished
# 	consonants
# 	parameterizations
# 	hypergraph
# 	underestimation
# 	geostatistical
# 	timelines
# 	linearnonlinear
# 	hybridization
# 	mcallester
# 	pioneered
# 	thermodynamics
# 	missingness
# 	missforest
# 	inversions
# Some words which never appear in Statistics papers:
# 	historically
# 	randomised
# 	hematoxylin
# 	histopathological
# 	worldwide
# 	recognizer
# 	prevailing
# 	displayed
# 	correspondent
# 	reordering
# 	watermarking
# 	watermark
# 	watermarked
# 	skeletons
# 	concatenation
# 	devanagari
# 	starcraft
# 	controllers
# 	micromanagement
# 	marginalises

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.060912151821243e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7425
